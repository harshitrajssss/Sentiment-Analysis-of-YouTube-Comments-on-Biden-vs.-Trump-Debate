# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitrajssss/Sentiment-Analysis-of-YouTube-Comments-on-Biden-vs.-Trump-Debate/blob/main/Untitled71.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyLDAvis
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 13.7 MB/s eta 0:00:00
# ...

# %%
dev = "AIzaSyCXVcCP3aZkQn-h-srYk4w3O9S6hZkRW7A"

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="qqG96G8YdcE",
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="qqG96G8YdcE", maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df_debate= pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df_debate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76578 entries, 0 to 76577
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      76578 non-null  object
#  1   updated_at  76578 non-null  object
#  2   like_count  76578 non-null  int64
#  3   text        76578 non-null  object
#  4   public      76578 non-null  bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 2.4+ MB

# %%
import pandas as pd
df_debate=pd.read_csv('/content/drive/MyDrive/debate.csv')

# %%
df_debate['like_count'].sum()
# Out:
# 1341471

# %%
df_debate['author'].shape  #####unique().shape
# Out:
# (76578,)

# %%
df_debate.sort_values(by='like_count', ascending=False)[0:100]
# Out:
#        Unnamed: 0               author            updated_at  like_count  \
# 69003       69003       @WAGNERLEONARD  2024-06-28T06:33:09Z       71030
# 76360       76360            @Mikecarz  2024-06-28T02:54:32Z       63359
# 56572       56572          @SKRILLA777  2024-06-28T11:07:21Z       53328
# 75207       75207    @PieroMinayaRojas  2024-06-28T03:57:07Z       39368
# 76487       76487     @richardford9818  2024-06-28T02:43:54Z       37120
# ...           ...                  ...                   ...         ...
# 20474       20474  @The.Dork.Ages_8808  2024-06-29T06:45:47Z        1066
# 36372       36372     @BlueAppleEntNyc  2024-06-28T18:17:10Z        1058
# 19119       19119     @bettybunbun9664  2024-06-29T08:52:58Z        1051
# 76295       76295       @californiannn  2024-06-28T03:00:19Z        1044
# 74900       74900             @shko-mi  2024-06-28T04:08:44Z        1017
#
#                                                     text  public
# ...

# %%
from textblob import TextBlob
df_debate['text'] = df_debate['text'].astype(str)
df_debate['sentiment_score'] = df_debate['text'].apply(lambda x: TextBlob(x).sentiment.polarity)
# Out:
#        Unnamed: 0              author            updated_at  like_count  \
# 37392       37392   @AdeelPasha-sl9ei  2024-06-28T17:49:33Z           0
# 44453       44453      @bennmitey8126  2024-06-28T15:03:45Z           0
# 44455       44455   @phenomeninja1855  2024-06-28T15:03:44Z           0
# 44456       44456  @rafaeluryayev7174  2024-06-28T15:03:43Z           0
# 44457       44457           @lan_real  2024-06-28T15:03:35Z           0
# ...           ...                 ...                   ...         ...
# 44535       44535    @activeworld9055  2024-06-28T15:02:09Z           0
# 44537       44537     @aaronsowell259  2024-06-28T15:02:08Z           0
# 44538       44538  @mauricemacsay2087  2024-06-28T15:02:07Z           0
# 44540       44540         @Roojules98  2024-06-28T15:02:05Z           0
# 44542       44542    @activeworld9055  2024-06-28T15:02:05Z           0
#
#                                                     text  public  \
# ...

# %%
df_debate.sort_values(by='like_count', ascending=False)[0:100]
# Out:
#        Unnamed: 0               author            updated_at  like_count  \
# 69003       69003       @WAGNERLEONARD  2024-06-28T06:33:09Z       71030
# 76360       76360            @Mikecarz  2024-06-28T02:54:32Z       63359
# 56572       56572          @SKRILLA777  2024-06-28T11:07:21Z       53328
# 75207       75207    @PieroMinayaRojas  2024-06-28T03:57:07Z       39368
# 76487       76487     @richardford9818  2024-06-28T02:43:54Z       37120
# ...           ...                  ...                   ...         ...
# 20474       20474  @The.Dork.Ages_8808  2024-06-29T06:45:47Z        1066
# 36372       36372     @BlueAppleEntNyc  2024-06-28T18:17:10Z        1058
# 19119       19119     @bettybunbun9664  2024-06-29T08:52:58Z        1051
# 76295       76295       @californiannn  2024-06-28T03:00:19Z        1044
# 74900       74900             @shko-mi  2024-06-28T04:08:44Z        1017
#
#                                                     text  public  \
# ...

# %%
import re
import pandas as pd
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    return text

df_debate['processed_text'] = df_debate['text'].apply(preprocess_text)

stop_words = set(stopwords.words('english'))
df_debate['tokens'] = df_debate['processed_text'].apply(lambda x: [word for word in word_tokenize(x) if word not in stop_words])

all_tokens = [token for sublist in df_debate['tokens'] for token in sublist]
word_counts = Counter(all_tokens)
top_30_words = word_counts.most_common(10000)
top_30_words_df = pd.DataFrame(top_30_words, columns=['word', 'count'])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
top_30_words_df.to_csv('/content/drive/MyDrive/top_30_words.csv')

# %%
top_30_words_df.head(50)
# Out:
#          word  count
# 0       biden  31062
# 1       trump  22922
# 2        like   7348
# 3   president   7274
# 4      debate   5828
# 5      people   5816
# 6         joe   5533
# 7     country   4411
# 8     america   4286
# 9          us   4213
# 10        one   4186
# 11       dont   4081
# 12         im   3682
# 13       even   3635
# 14       time   3385
# 15      world   3364
# 16       cant   3169
# 17      would   3061
# 18        hes   2957
# 19        old   2916
# 20       know   2835
# 21        get   2778
# 22      think   2723
# 23        two   2722
# 24       vote   2703
# 25       said   2623
# 26        man   2451
# 27         go   2442
# 28   american   2409
# 29     really   2285
# 30     better   2275
# 31     bidens   2275
# 32       need   2258
# 33       good   2254
# 34        say   2241
# 35      years   2182
# 36        see   2165
# 37        way   2152
# 38       2024   2150
# 39       idea   2120
# 40       best   2110
# 41       make   1968
# ...

# %%
common_stop_words = [
    'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves',
    'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their',
    'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are',
    'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an',
    'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about',
    'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up',
    'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when',
    'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor',
    'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should',
    'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven',
    'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn','like','also','would'
]
more_common_stop_words = [
    'like', 'also', 'would', 'could', 'should', 'might', 'must', 'need', 'ought', 'shall', 'will', 'won', 'can',
    'cannot', 'could', 'would', 'should', 'might', 'must', 'need', 'ought', 'shall', 'shouldn', 'won', 'ain',
    'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan',
    'shouldn', 'wasn', 'weren', 'wouldn',
    'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves',
    'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their',
    'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are',
    'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an',
    'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about',
    'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up',
    'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when',
    'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor',
    'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'just', 'don', 'now', 'd', 'll',
    'm', 'o', 're', 've', 'y'
]

youtube_common_words = [
    'like', 'subscribe', 'video', 'channel', 'comment', 'share', 'watch', 'content', 'please', 'awesome',
    'amazing', 'love', 'great', 'good', 'nice', 'thanks', 'thank', 'helpful', 'informative', 'interesting',
    'cool', 'best', 'wonderful', 'funny', 'lol', 'haha', 'hilarious', 'beautiful', 'music', 'song', 'listen',
    'watching', 'views', 'subscribed', 'hit', 'button', 'notification', 'bell', 'follow', 'guys', 'everyone',
    'people', 'anyone', 'someone', 'guys', 'check', 'out', 'link', 'bio', 'description', 'new', 'upload', 'update',
    'post', 'posted', 'latest', 'video', 'today', 'yesterday', 'soon', 'first', 'second', 'minute', 'hour', 'day',
    'week', 'month', 'year', 'favorite', 'part', 'moment', 'scene', 'clips', 'recommend', 'suggest', 'idea', 'tips',
    'tutorial', 'guide', 'review', 'reaction', 'vlog', 'daily', 'live', 'stream', 'streaming', 'games', 'gaming',
    'play', 'played', 'playing', 'gameplay', 'episode', 'series', 'season', 'part', 'episode', 'show', 'movie',
    'film', 'actor', 'actress', 'director', 'producer', 'scene', 'trailer', 'behind', 'scenes', 'footage',
    'spoiler', 'alert', 'plot', 'story', 'ending', 'beginning', 'middle', 'character', 'role', 'performance',
    'cast', 'crew', 'script', 'dialogue', 'lines', 'comedy', 'drama', 'action', 'romance', 'thriller', 'horror',
    'sci-fi', 'fantasy', 'adventure', 'mystery', 'animation', 'cartoon', 'documentary', 'biography', 'feature',
    'short', 'full', 'length', 'series', 'episode', 'season', 'show', 'play', 'pause', 'stop', 'forward',
    'backward', 'skip', 'volume', 'mute', 'unmute', 'fullscreen', 'exit', 'minimize', 'maximize', 'quality',
    'resolution', 'HD', 'SD', '4K', '8K', '1080p', '720p', '480p', '360p', '240p', '144p', 'live', 'stream',
    'buffering', 'loading', 'buffer', 'lag', 'delay', 'skip', 'fast', 'slow', 'replay', 're-upload', 'deleted',
    'removed', 'blocked', 'banned', 'copyright', 'strike', 'claim', 'notice', 'warning', 'appeal', 'counter',
    'dispute', 'guidelines', 'terms', 'conditions', 'policy', 'community', 'standards', 'rules', 'regulations',
    'violations', 'infringement', 'offensive', 'abusive', 'inappropriate', 'explicit', 'mature', 'adult',
    'sensitive', 'triggering', 'disturbing', 'graphic', 'violent', 'sexual', 'nudity', 'gore', 'drugs',
    'alcohol', 'substance', 'abuse', 'self-harm', 'suicide', 'bullying', 'harassment', 'hate', 'speech',
    'discrimination', 'racism', 'sexism', 'homophobia', 'transphobia', 'misogyny', 'misandry', 'ableism',
    'ageism', 'classism', 'ethnocentrism', 'xenophobia', 'censorship', 'freedom', 'expression', 'rights',
    'privacy', 'data', 'protection', 'security', 'hacking', 'phishing', 'scam', 'fraud', 'deception', 'cheating',
    'manipulation', 'exploitation', 'spam', 'advertising', 'promotion', 'marketing', 'branding', 'sponsorship',
    'endorsement', 'influencer', 'celebrity', 'personality', 'host', 'guest', 'collaboration', 'partnership',
    'network', 'community', 'forum', 'discussion', 'comment', 'thread', 'reply', 'response', 'reaction',
    'feedback', 'opinion', 'review', 'rating', 'like', 'dislike', 'thumbs', 'up', 'down', 'emoji', 'emoticon',
    'smiley', 'face', 'heart', 'star', 'check', 'mark', 'exclamation', 'question', 'hashtag', 'tag', 'mention',
    'share', 'retweet', 'repost', 'quote', 'link', 'URL', 'website', 'blog', 'article', 'post', 'message',
    'chat', 'DM', 'PM', 'private', 'group', 'public', 'admin', 'moderator', 'support', 'help', 'faq', 'guide',
    'tutorial', 'instructions', 'manual', 'document', 'PDF', 'download', 'upload', 'save', 'share', 'export',
    'import', 'sync', 'backup', 'restore', 'recovery', 'reset', 'settings', 'preferences', 'options',
    'configuration', 'customization', 'theme', 'layout', 'design', 'interface', 'UI', 'UX', 'navigation',
    'menu', 'toolbar', 'button', 'icon', 'logo', 'brand', 'title', 'header', 'footer', 'sidebar', 'panel',
    'window', 'tab', 'screen', 'monitor', 'display', 'resolution', 'aspect', 'ratio', 'fullscreen', 'maximize',
    'minimize', 'resize', 'move', 'drag', 'drop', 'click', 'double', 'right', 'left', 'scroll', 'zoom', 'pinch',
    'rotate', 'swipe', 'gesture', 'touch', 'tap', 'hold', 'release', 'input', 'output', 'device', 'hardware',
    'software', 'program', 'application', 'app', 'platform', 'system', 'OS', 'operating', 'server', 'client',
    'network', 'internet', 'web', 'website', 'domain', 'host', 'hosting', 'cloud', 'service', 'provider',
    'subscription', 'membership', 'account', 'profile', 'user', 'admin', 'password', 'login', 'logout',
    'register', 'sign', 'up', 'down', 'agreement', 'contract', 'terms', 'conditions', 'policy', 'privacy',
    'security', 'settings', 'preferences', 'options', 'configuration', 'setup', 'installation', 'uninstall',
    'update', 'upgrade', 'patch', 'release', 'beta', 'version', 'compatible', 'incompatible', 'support',
    'help', 'faq', 'guide', 'tutorial', 'manual', 'instructions', 'document', 'PDF', 'download', 'upload',
    'save', 'share', 'export', 'import', 'sync', 'backup', 'restore', 'recovery', 'reset', 'settings',
    'preferences', 'options', 'configuration', 'customization', 'theme', 'layout', 'design', 'interface', 'UI',
    'UX', 'navigation', 'menu', 'toolbar', 'button', 'icon', 'logo', 'brand', 'title', 'header', 'footer',
    'sidebar', 'panel', 'window', 'tab', 'screen', 'monitor', 'display', 'resolution', 'aspect', 'ratio',
    'fullscreen', 'maximize', 'minimize', 'resize', 'move', 'drag', 'drop', 'click', 'double', 'right', 'left',
    'scroll', 'zoom', 'pinch', 'rotate', 'swipe', 'gesture', 'touch', 'tap', 'hold', 'release', 'input', 'output',
    'device', 'hardware', 'software', 'program', 'application', 'app', 'platform', 'system', 'OS', 'operating',
    'server', 'client', 'network', 'internet', 'web', 'website', 'domain', 'host', 'hosting', 'cloud', 'service',
    'provider', 'subscription', 'membership', 'account', 'profile', 'user', 'admin', 'password', 'login',
    'logout', 'register', 'sign', 'up', 'down', 'agreement', 'contract', 'terms', 'conditions', 'policy',
    'privacy', 'security', 'settings', 'preferences', 'options', 'configuration', 'setup', 'installation',
    'uninstall', 'update','us','get','still','much','thats','back','thick','say','would','think','really','looks','needs','never','every','doesnt','didnt','saying','talking']

commom_words=set(common_stop_words+youtube_common_words+more_common_stop_words)

# %%
top_30_words_df = top_30_words_df[top_30_words_df['word'].str.len() >= 5]
top_30_words_df.head(30)
# Out:
#          word  count
# 0       biden  31062
# 1       trump  22922
# 3   president   7274
# 4      debate   5828
# 5      people   5816
# 7     country   4411
# 8     america   4286
# 15      world   3364
# 17      would   3061
# 22      think   2723
# 28   american   2409
# 29     really   2285
# 30     better   2275
# 31     bidens   2275
# 35      years   2182
# 42      going   1964
# 43      right   1921
# 47      still   1767
# 48  americans   1723
# 49      looks   1719
# 51      needs   1684
# 56      never   1635
# 57      thats   1622
# 59      every   1575
# 60     doesnt   1572
# 62      didnt   1526
# 65      great   1395
# 67     saying   1391
# 69      watch   1379
# 70    talking   1366

# %%
top_30_words_df = top_30_words_df[~top_30_words_df['word'].isin(commom_words)]

# %%
top_30_words_df['count'].sum()
# Out:
# 419717

# %%
top_30_words_df.head(100)
# Out:
#           word  count
# 0        biden  31062
# 1        trump  22922
# 3    president   7274
# 4       debate   5828
# 7      country   4411
# ..         ...    ...
# 239     family    562
# 241     matter    557
# 242      white    557
# 243     change    555
# 244      stage    555
#
# [100 rows x 2 columns]

# %%
top_30_words_df[top_30_words_df['word']=='white']
# Out:
#       word  count
# 242  white    557

# %%
words_to_filter = ['biden']
pattern = '|'.join(words_to_filter)
filtered_comments = df_debate[df_debate['processed_text'].str.contains(pattern, case=False, na=False)]
print(filtered_comments)
# Out:
#        Unnamed: 0                         author            updated_at  \
# 0               0                           @wsj  2024-06-28T18:43:11Z
# 1               1  @musicthelanguagemiariozo1572  2024-07-04T18:33:46Z
# 2               2                @dretownsend925  2024-07-04T18:33:25Z
# 4               4             @vanessacanary5154  2024-07-04T18:30:32Z
# 7               7                    @kelticpain  2024-07-04T18:29:59Z
# ...           ...                            ...                   ...
# 76563       76563                @uioongbion2074  2024-06-28T02:40:42Z
# 76567       76567                @ClaudeMagicbox  2024-06-28T02:40:34Z
# 76568       76568            @tylerhernandez5978  2024-06-28T02:40:32Z
# 76569       76569                @alexiscruz3368  2024-06-28T02:40:31Z
# 76571       76571                @atarijones5056  2024-06-28T02:40:21Z
#
#        like_count                                               text  public  \
# ...

# %%
filter_df=pd.DataFrame(filtered_comments)

# %%
filter_df.head(20)
# Out:
#     Unnamed: 0                         author            updated_at  \
# 0            0                           @wsj  2024-06-28T18:43:11Z
# 1            1  @musicthelanguagemiariozo1572  2024-07-04T18:33:46Z
# 2            2                @dretownsend925  2024-07-04T18:33:25Z
# 4            4             @vanessacanary5154  2024-07-04T18:30:32Z
# 7            7                    @kelticpain  2024-07-04T18:29:59Z
# 13          13              @meredithhall5055  2024-07-04T18:26:45Z
# 18          18              @meredithhall5055  2024-07-04T18:20:39Z
# 21          21              @geniushughes8287  2024-07-04T18:19:02Z
# 24          24              @geniushughes8287  2024-07-04T18:16:29Z
# 25          25                       @HereXEG  2024-07-04T18:16:04Z
# 30          30                   @JennSalerno  2024-07-04T18:14:56Z
# 32          32                   @hanoisaigon  2024-07-04T18:12:49Z
# 33          33             @patsyhairston8277  2024-07-04T18:12:01Z
# ...

# %%
filter_df['sentiment_score'].mean()
# Out:
# 0.07910368511910902

# %%
from transformers import pipeline

# %%
from transformers import pipeline

sentiment_pipeline = pipeline('sentiment-analysis')

def get_sentiment(text):
    # Truncate text to the maximum length the model can handle
    max_length = 512
    if len(text) > max_length:
        text = text[:max_length]
    result = sentiment_pipeline(text)[0]
    return result['label'], result['score']

filter_df[['sentiment', 'score']] = filter_df['text'].apply(lambda x: pd.Series(get_sentiment(x)))
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
filter_df.to_csv('/content/drive/MyDrive/filter_df_biden.csv')

# %%
filter_df[['text','sentiment','score']].head(100)
# Out:
#                                                   text sentiment     score
# 0    Unsteady Biden, a Subdued Trump: The Debate An...  NEGATIVE  0.985595
# 1    Watching From India.. I believe America will b...  POSITIVE  0.751301
# 2    Biden sound like SpongeBob when he needed some...  NEGATIVE  0.992794
# 4                       My face when Biden talk 😮😮😮😮😮😮  POSITIVE  0.953634
# 7    "there was no inflation when i became presiden...  POSITIVE  0.994314
# ..                                                 ...       ...       ...
# 273                               Biden must step down  NEGATIVE  0.996649
# 278  Respect to trump for standing there and listen...  POSITIVE  0.985571
# 286  "There was no inflation when I became presiden...  POSITIVE  0.979704
# 288  Biden just mumbles incoherently, i cant unders...  NEGATIVE  0.999722
# 299                Biden is lost… pretty embarrassing!  NEGATIVE  0.999764
#
# [100 rows x 3 columns]

# %%
filter_df[filter_df['sentiment']=='NEGATIVE']['like_count'].sum()
# Out:
# 433984

# %%
filter_df_trump=pd.read_csv('/content/drive/MyDrive/filter_df_trump.csv')

# %%
filter_df_trump[filter_df_trump['sentiment']=='NEGATIVE']['like_count'].sum()
# Out:
# 178870

# %% [markdown]
# total likes=1341471
#
# total_likes_for negative_comments_biden=433984
#
# total_likes_for negative_comments_trump=178870
#
# negative_sentiment_biden=33%
#
# negative_sentiment_trump=13%
